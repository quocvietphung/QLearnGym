# %%
from qlearning.train import train_agent
from qlearning.evaluate import evaluate_agent
from qlearning.utils import load_qtable

# Huấn luyện agent
q_table, rewards = train_agent(
    env_name='Taxi-v3',
    num_episodes=3000,
    max_steps=100,
    alpha=0.7,
    gamma=0.95,
    epsilon=1.0,
    epsilon_min=0.1,
    epsilon_decay=0.995,
    model_path="models/qtable.npy",
    plot_path="results/rewards.png"
)

# Đánh giá agent
evaluate_agent(
    q_table_path="models/qtable.npy",
    env_name='Taxi-v3',
    episodes=100,
    render=False
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode 100/3000 - Reward: -316.00 - Epsilon: 0.9900
# Episode 200/3000 - Reward: -406.00 - Epsilon: 0.9851
# Episode 300/3000 - Reward: -406.00 - Epsilon: 0.9655
# Episode 400/3000 - Reward: -343.00 - Epsilon: 0.9511
# Episode 500/3000 - Reward: -397.00 - Epsilon: 0.9092
# Episode 600/3000 - Reward: -66.00 - Epsilon: 0.7941
# Episode 700/3000 - Reward: -67.00 - Epsilon: 0.4957
# Episode 800/3000 - Reward: -15.00 - Epsilon: 0.3003
# Episode 900/3000 - Reward: 6.00 - Epsilon: 0.1819
# Episode 1000/3000 - Reward: 0.00 - Epsilon: 0.1102
# Episode 1100/3000 - Reward: -19.00 - Epsilon: 0.0997
# Episode 1200/3000 - Reward: 11.00 - Epsilon: 0.0997
# Episode 1300/3000 - Reward: 9.00 - Epsilon: 0.0997
# Episode 1400/3000 - Reward: -6.00 - Epsilon: 0.0997
# Episode 1500/3000 - Reward: 2.00 - Epsilon: 0.0997
# Episode 1600/3000 - Reward: 9.00 - Epsilon: 0.0997
# Episode 1700/3000 - Reward: -13.00 - Epsilon: 0.0997
# Episode 1800/3000 - Reward: 9.00 - Epsilon: 0.0997
# Episode 1900/3000 - Reward: 8.00 - Epsilon: 0.0997
# Episode 2000/3000 - Reward: 0.00 - Epsilon: 0.0997
# Episode 2100/3000 - Reward: 12.00 - Epsilon: 0.0997
# Episode 2200/3000 - Reward: -17.00 - Epsilon: 0.0997
# Episode 2300/3000 - Reward: -8.00 - Epsilon: 0.0997
# Episode 2400/3000 - Reward: 6.00 - Epsilon: 0.0997
# Episode 2500/3000 - Reward: 9.00 - Epsilon: 0.0997
# Episode 2600/3000 - Reward: -13.00 - Epsilon: 0.0997
# Episode 2700/3000 - Reward: 9.00 - Epsilon: 0.0997
# Episode 2800/3000 - Reward: 0.00 - Epsilon: 0.0997
# Episode 2900/3000 - Reward: -5.00 - Epsilon: 0.0997
# Episode 3000/3000 - Reward: 6.00 - Epsilon: 0.0997
# ✅ Q-table saved to: models/qtable.npy
# 📈 Reward plot saved to: results/rewards.png
# 📥 Q-table loaded from: models/qtable.npy
# 🎯 Evaluation over 100 episodes — Avg reward: 8.05
# 8.05
